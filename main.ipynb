# %% [markdown]
# # Antes de empezar :
#    - Estos ejercicios están relacionados con las lecciones Subconjunto y Estadísticas descriptivas.
#    - Tenga en cuenta que necesitará utilizar algunas de las funciones que aprendió en las lecciones anteriores.
#    - Todos los conjuntos de datos se proporcionan en la carpeta `your-code` de este laboratorio.
#    - Elabora tus códigos y resultados tanto como puedas.
#    - Esfuérzate al máximo para responder a las preguntas y completar las tareas y, sobre todo, ¡¡¡disfruta del proceso!!!

# %% [markdown]
# #### Importa todas las librerías necesarias

# %%
# import libraries here
import numpy as np
import pandas as pd
import csv
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Desafío 1

# %% [markdown]
# #### En este reto utilizaremos el archivo `Temp_States.csv`.
#
# #### Primero impórtalo en un marco de datos llamado `temp`.

# %%
# YOUR CODE HERE
df_temp = pd.read_csv("C:/Users/Khaled/Desktop/IRON HACK/Tasks/Sesión 39 Subconjuntos y estadísticas descriptivas/Temp_States.csv")

# %% [markdown]
# #### Print `temp`

# %%
# your solution here
print(list(df_temp))
df_temp.head()
# Out:
# ['City', 'State', 'Temperature']
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444

# %% [markdown]
# #### Explore los tipos de datos del marco de datos Temp. ¿Qué tipo de datos tenemos? Comenta tu resultado.

# %%
# YOUR CODE HERE
print(df_temp.dtypes)
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Selecciona las filas en las que el estado es New York

# %%
# YOUR CODE HERE
df_temp_ny = df_temp[df_temp['State'] == 'New York']
df_temp_ny.head()
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### ¿Cuál es la temperatura media de las ciudades de Nueva York?

# %%
# YOUR CODE HERE
avg_ny = df_temp_ny['Temperature'].mean()
avg_ny
# Out:
# np.float64(10.74074074074074)

# %% [markdown]
# #### Queremos conocer las ciudades y estados con temperaturas superiores a 15 grados centígrados.

# %%
# your answer here
temp_15 = df_temp[df_temp['Temperature'] > 15]
print(temp_15[['State', 'City' ]])
# Out:
#          State      City
# 0     New York       NYC
# 3  Connecticut  Hartford
# 5   New Jersey    Treton
# 6   New Jersey    Newark

# %% [markdown]
# #### Ahora, devuelva sólo las ciudades que tengan una temperatura superior a 15 grados centígrados.

# %%
# YOUR CODE HERE
print(temp_15['City'])
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### Queremos saber qué ciudades tienen una temperatura superior a 15 grados Celcius e inferior a 20 grados Celcius
#
# *Pista: Primero escriba la condición y luego seleccione las filas.

# %%
# YOUR CODE HERE
temp_15_20 = df_temp[(df_temp['Temperature'] > 15) & (df_temp['Temperature'] < 20)]
print(temp_15_20['City'])
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %%
df_temp['State'].value_counts()
# Out:
# State
# New York       3
# Connecticut    2
# New Jersey     2
# Name: count, dtype: int64

# %% [markdown]
# #### Halla la media y la desviación estándar de la temperatura de cada estado.
#
# *Pista: Utiliza las funciones de la lección Manipulación de datos*.

# %%
# YOUR CODE HERE
result = df_temp.groupby('State')['Temperature'].agg(['mean', 'std'])
result
# Out:
#                   mean       std
# State
# Connecticut  15.833333  1.964186
# New Jersey   21.111111  1.571348
# New York     10.740741  8.133404

# %% [markdown]
# # Desafío 2

# %% [markdown]
# #### Cargar el fichero `employee.csv` en un DataFrame. Llama al dataframe `employee`.

# %%
# YOUR CODE HERE
employee = pd.read_csv("C:/Users/Khaled/Desktop/IRON HACK/Tasks/Sesión 39 Subconjuntos y estadísticas descriptivas/employee.csv")

# %% [markdown]
# #### Explore los tipos de datos del marco de datos Temp. Comenta tus resultados

# %%
# YOUR CODE HERE
print(employee.dtypes)
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Muestre visualmente la distribución de frecuencias (histograma) del conjunto de datos de empleados. Describa en pocas palabras estos histogramas.

# %%
# your answer here
plt.figure(figsize=(10,6))
ax = sns.barplot(x='Name', y='Years', data=employee, palette='Blues_d')
plt.title('Frecuencia', fontsize = 20)
plt.ylabel('Years worked', fontsize = 13)
plt.xlabel('Employee Name', fontsize = 13)
# Out:
# C:\Users\Khaled\AppData\Local\Temp\ipykernel_6904\2380351930.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Name', y='Years', data=employee, palette='Blues_d')
# Text(0.5, 0, 'Employee Name')

# %%
# YOUR CODE HERE

# %%
# YOUR CODE HERE

# %% [markdown]
# #### ¿Cuál es el salario medio en esta empresa?

# %%
# YOUR CODE HERE
salario_medio = employee['Salary'].mean()
salario_medio
# Out:
# np.float64(48.888888888888886)

# %% [markdown]
# #### ¿Cuál es el salario más alto?

# %%
# YOUR CODE HERE
max_salary = employee['Salary'].max()
max_salary
# Out:
# np.int64(70)

# %% [markdown]
# #### ¿Cuál es el salario más bajo?

# %%
# YOUR CODE HERE
min_salary = employee['Salary'].min()
min_salary
# Out:
# np.int64(30)

# %% [markdown]
# #### ¿Quiénes son los empleados con el salario más bajo?

# %%
# YOUR CODE HERE
x = employee[employee['Salary'] == min_salary]
x
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### ¿Podría darnos toda la información sobre un empleado llamado David?

# %%
# YOUR CODE HERE
y = employee[employee['Name'] == 'David']
y
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### ¿Podría dar sólo el sueldo de David?

# %%
# YOUR CODE HERE
david_salary = employee[employee['Name'] == 'David']['Salary']
david_salary
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Printea todas las líneas en las que el cargo es asociado

# %%
# YOUR CODE HERE
z = employee[employee['Salary'] == david_salary.values[0]]
print(z)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Printea las 3 primeras filas de tu dataframe
#
# ##### Consejo : Hay 2 maneras de hacerlo. Hazlo de las dos maneras

# %%
# YOUR CODE HERE
print(employee.head(3))
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# YOUR CODE HERE
print(employee[:3])
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### ¿Encuentra a los empleados cuyo cargo es asociado y cuyo salario es superior a 55?

# %%
# YOUR CODE HERE
Salary_55 = employee[employee['Salary'] > 55]
Salary_55
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Agrupa a los empleados en función del número de años que llevan trabajando. ¿Cuáles son los salarios medios de cada grupo?

# %%
# YOUR CODE HERE
avg_salar_year = employee.groupby('Years')['Salary'].agg(['mean'])
avg_salar_year
# Out:
#             mean
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# #### ¿Cuál es el salario medio por título?

# %%
# YOUR CODE HERE
avg_salar_title = employee.groupby('Title')['Salary'].agg(['mean'])
avg_salar_title
# Out:
#                 mean
# Title
# VP         70.000000
# analyst    32.500000
# associate  56.666667

# %% [markdown]
# #### Muestra un resumen visual de los datos utilizando boxplot. ¿Cuáles son los cuartiles primero y tercero? Comenta tus resultados.
#
# * Pista : Cuantiles vs Cuartiles*.
# En Probabilidad y Estadística, los cuantiles son puntos de corte que dividen el rango de una distribución de probabilidad en intervalos continuos con probabilidades iguales. Cuando la división es en cuatro partes, los valores de la variable correspondientes al 25%, 50% y 75% de la distribución total se denominan cuartiles.

# %%
# YOUR CODE HERE
employee.boxplot(column="Salary")
plt.show()

# %%
# print first quartile here
q1 = employee['Salary'].quantile(0.25)
print("First quartile of Salary:", q1)
# Out:
# First quartile of Salary: 35.0

# %%
# print third quartile here
q3 = employee['Salary'].quantile(0.75)
print("First quartile of Salary:", q3)
# Out:
# First quartile of Salary: 60.0

# %% [markdown]
# #### ¿Es diferente el salario medio por género?

# %%
# your answer here
avg_salar_gender = employee.groupby('Gender')['Salary'].agg(['mean'])
avg_salar_gender
# Out:
#         mean
# Gender
# F       47.5
# M       50.0

# %% [markdown]
# #### Encuentra el mínimo, la media y el máximo de todas las columnas numéricas para cada Departamento.
#
# ##### Sugerencia: Utiliza las funciones de la lección Manipulación de Datos

# %%
# your answer here
mmm = employee[['Salary','Years']].agg(['min','mean','max']).round(2)
mmm
# Out:
#       Salary  Years
# min    30.00   1.00
# mean   48.89   4.11
# max    70.00   8.00

# %% [markdown]
# ### Pregunta bonus
#
# #### Para cada departamento, calcule la diferencia entre el salario máximo y el salario mínimo.
#
# ##### * Sugerencia: pruebe a utilizar `agg` o `apply` y `lambda`*.

# %%
# your answer here

# %% [markdown]
# # Desafío 3

# %% [markdown]
# #### Abra el conjunto de datos Orders.csv. Nombre el conjunto de datos pedidos

# %%
# your answer here
orders = pd.read_csv("C:/Users/Khaled/Desktop/IRON HACK/Tasks/Sesión 39 Subconjuntos y estadísticas descriptivas/Orders.csv")

# %% [markdown]
# #### Explore su conjunto de datos observando los tipos de datos y las estadísticas de resumen. Comenta tus resultados

# %%
# your answer here
print(orders.dtypes)
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
# your answer here
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %% [markdown]
# #### ¿Cuál es el precio medio de compra?

# %%
# your answer here
avg_purch = orders['amount_spent'].agg('mean').round(2)
avg_purch
# Out:
# np.float64(22.39)

# %% [markdown]
# #### ¿Cuáles fueron los precios de compra más altos y más bajos?

# %%
# your answer here
max_pruch = orders['amount_spent'].max().round(2)
max_pruch
# Out:
# np.float64(168469.6)

# %%
# your answer here
min_pruch = orders['amount_spent'].min().round(2)
min_pruch
# Out:
# np.float64(0.0)

# %%
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %% [markdown]
# #### Seleccione todos los clientes que tenemos en España

# %%
# your answer here
customers_es = orders[orders['Country'] == 'Spain']
customers_es
# Out:
#             id  InvoiceNo StockCode  year  month  day  hour  \
# 4250      6421     536944     22383  2010     12    5    12
# 4251      6422     536944     22384  2010     12    5    12
# 4252      6423     536944     20727  2010     12    5    12
# 4253      6424     536944     20725  2010     12    5    12
# 4254      6425     536944     20728  2010     12    5    12
# ...        ...        ...       ...   ...    ...  ...   ...
# 394733  535271     581193     23291  2011     12    3    17
# 394734  535272     581193    85232D  2011     12    3    17
# 394735  535273     581193     22721  2011     12    3    17
# 394736  535274     581193     23241  2011     12    3    17
# 394737  535275     581193     23247  2011     12    3    17
#
#                           Description  Quantity          InvoiceDate  \
# 4250          lunch bag suki  design         70  2010-12-03 12:20:00
# 4251          lunch bag pink polkadot       100  2010-12-03 12:20:00
# ...

# %% [markdown]
# #### ¿Cuántos clientes tenemos en España?
# ##### Pista : Utiliza value_counts()

# %%
# your answer here
orders = orders.rename(columns={'Unnamed: 0':'id'})
count_es = customers_es['Country'].value_counts()
count_es
# Out:
# Country
# Spain    2485
# Name: count, dtype: int64

# %% [markdown]
# #### Selecciona todos los clientes que han comprado más de 50 artículos ?

# %%
# your answer here
customer_50 = orders[orders['Quantity']> 50] 
customer_50
# Out:
#             id  InvoiceNo StockCode  year  month  day  hour  \
# 46          46     536371     22086  2010     12    3     9
# 83          83     536376     21733  2010     12    3     9
# 96          96     536378     21212  2010     12    3     9
# 102        102     536378    85071B  2010     12    3     9
# 174        176     536386    85099C  2010     12    3     9
# ...        ...        ...       ...   ...    ...  ...   ...
# 397720  541702     581566     23404  2011     12    5    11
# 397721  541703     581567     21417  2011     12    5    11
# 397729  541711     581567     21326  2011     12    5    11
# 397761  541746     581571     23167  2011     12    5    12
# 397882  541867     581584     20832  2011     12    5    12
#
#                                Description  Quantity          InvoiceDate  \
# 46         paper chain kit 50's christmas         80  2010-12-01 09:00:00
# 83        red hanging heart t-light holder        64  2010-12-01 09:32:00
# ...

# %% [markdown]
# #### Selecciona pedidos de España superiores a 50 artículos

# %%
# your answer here
customers_es_50 = customers_es[customers_es['Quantity'] > 50]
customers_es_50
# Out:
#             id  InvoiceNo StockCode  year  month  day  hour  \
# 4250      6421     536944     22383  2010     12    5    12
# 4251      6422     536944     22384  2010     12    5    12
# 4252      6423     536944     20727  2010     12    5    12
# 4253      6424     536944     20725  2010     12    5    12
# 4254      6425     536944     20728  2010     12    5    12
# 32454    52416     540785    84997B  2011      1    2    11
# 32455    52417     540785    84997D  2011      1    2    11
# 32456    52418     540785    84997C  2011      1    2    11
# 32457    52419     540785    84997A  2011      1    2    11
# 91155   136767     547972     22383  2011      3    1    16
# 91156   136768     547972     22384  2011      3    1    16
# 91159   136771     547972     20728  2011      3    1    16
# 174442  248797     558871     22384  2011      7    1    13
# 174443  248798     558871     20727  2011      7    1    13
# 174444  248799     558871     20725  2011      7    1    13
# ...

# %% [markdown]
# #### Seleccionar todos los pedidos gratuitos

# %%
# your answer here
gratis = orders[orders['amount_spent'] == 0]
gratis
# Out:
#             id  InvoiceNo StockCode  year  month  day  hour  \
# 6914      9302     537197     22841  2010     12    7    14
# 22539    33576     539263     22580  2010     12    4    14
# 25379    40089     539722     22423  2010     12    2    13
# 29080    47068     540372     22090  2011      1    4    16
# 29082    47070     540372     22553  2011      1    4    16
# 34494    56674     541109     22168  2011      1    4    15
# 53788    86789     543599    84535B  2011      2    4    13
# 85671   130188     547417     22062  2011      3    3    10
# 92875   139453     548318     22055  2011      3    3    12
# 97430   145208     548871     22162  2011      4    1    14
# 107192  157042     550188     22636  2011      4    4    18
# 128641  187613     553000     47566  2011      5    4    15
# 137127  198383     554037     22619  2011      5    5    14
# 194648  279324     561284     22167  2011      7    2    12
# 197173  282912     561669     22960  2011      7    4    17
# ...

# %% [markdown]
# #### Seleccionar todos los pedidos que sean 'lunch bag
# #### Pista: Utilice las funciones de cadena

# %%
# your answer here
lunch_order = orders[orders['Description'].str.contains('lunch bag')]
lunch_order
# Out:
#             id  InvoiceNo StockCode  year  month  day  hour  \
# 93          93     536378     20725  2010     12    3     9
# 172        174     536385     22662  2010     12    3     9
# 354        363     536401     22662  2010     12    3    11
# 359        368     536401     20725  2010     12    3    11
# 360        369     536401     22382  2010     12    3    11
# ...        ...        ...       ...   ...    ...  ...   ...
# 397465  540436     581486     23207  2011     12    5     9
# 397713  541695     581538     20727  2011     12    5    11
# 397714  541696     581538     20725  2011     12    5    11
# 397877  541862     581581     23681  2011     12    5    12
# 397880  541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# 172     lunch bag dolly girl design        10  2010-12-01 09:56:00       1.65
# ...

# %% [markdown]
# #### Seleccione todos los pedidos realizados en 2011 y que sean «lunch bag».

# %%
# your answer here

lunch_order_2011 = orders[(orders['Description'].str.contains('lunch bag')) & (orders['year'] == 2011)]
lunch_order_2011
# Out:
#             id  InvoiceNo StockCode  year  month  day  hour  \
# 26340    42678     540015     20725  2011      1    2    11
# 26341    42679     540015     20726  2011      1    2    11
# 26512    42851     540023     22382  2011      1    2    12
# 26513    42852     540023     20726  2011      1    2    12
# 26860    43616     540098     22384  2011      1    2    15
# ...        ...        ...       ...   ...    ...  ...   ...
# 397465  540436     581486     23207  2011     12    5     9
# 397713  541695     581538     20727  2011     12    5    11
# 397714  541696     581538     20725  2011     12    5    11
# 397877  541862     581581     23681  2011     12    5    12
# 397880  541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# 26341            lunch bag woodland        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Muestra la distribución de frecuencias del importe gastado en España.

# %%
# your answer here
# plt.figure(figsize=(10, 6))

# # Plot histogram for men and women
# data[data['gender'] == 'M']['time'].plot(kind='hist', bins=30, density=True, alpha=0.5, label='Men', color='blue')
# data[data['gender'] == 'F']['time'].plot(kind='hist', bins=30, density=True, alpha=0.5, label='Women', color='pink')

# # Add labels and title
# plt.xlabel('Time (minutes)')
# plt.ylabel('Density')
# plt.title('Normalized Histogram of Times by Gender')
# plt.legend()
# plt.show()

# plt.figure(figsize=(10,6))
# customers_es['amount_spent'].plot(kind='hist', bins = 1200, density = True, alpha = 0.5, color='blue')
# plt.ylabel('year')
# plt.show()


plt.figure(figsize=(10, 6))
ax = sns.barplot(x='country', y='year', data=customers_es, palette='Blues_d')
plt.ylabel('Years', fontsize=13)
plt.xticks(rotation=45)  # Rotate x labels for better readability
plt.title('Years by Customer Name', fontsize=15)  # Optional title
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[154], line 22
#       1 # your answer here
#       2 # plt.figure(figsize=(10, 6))
#       3
#    (...)
#      17 # plt.ylabel('year')
#      18 # plt.show()
#      21 plt.figure(figsize=(10, 6))
# ---> 22 ax = sns.barplot(x='country', y='year', data=customers_es, palette='Blues_d')
#      23 plt.ylabel('Years', fontsize=13)
#      24 plt.xticks(rotation=45)  # Rotate x labels for better readability
#
# File c:\Users\Khaled\anaconda3\envs\notebook\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# ...

# %% [markdown]
# #### Seleccione todos los pedidos realizados en el mes de agosto

# %%
# your answer here
orders_aug = orders[orders['month'] == 8]
orders_aug
# Out:
#             id  InvoiceNo StockCode  year  month  day  hour  \
# 199475  285421     561904     22075  2011      8    1     8
# 199476  285422     561904    85049E  2011      8    1     8
# 199477  285423     561905     21385  2011      8    1     9
# 199478  285424     561905    84970L  2011      8    1     9
# 199479  285425     561905    84970S  2011      8    1     9
# ...        ...        ...       ...   ...    ...  ...   ...
# 226483  320688     565067     22644  2011      8    3    17
# 226484  320689     565067     22645  2011      8    3    17
# 226485  320690     565067     22637  2011      8    3    17
# 226486  320691     565067     22646  2011      8    3    17
# 226487  320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# 199476            scandinavian reds ribbons       156  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Seleccione cuántos pedidos se realizan por países en el mes de agosto
# ##### Pista: Utilice value_counts()

# %%
# your answer here
orders_aug.groupby('Country')['InvoiceNo'].value_counts()
# Out:
# Country         InvoiceNo
# Australia       563614       97
#                 563179       10
# Austria         562602       58
#                 563749       30
# Belgium         562034       39
#                              ..
# United Kingdom  564871        1
#                 564898        1
#                 564966        1
# Unspecified     564051       16
#                 563947        7
# Name: count, Length: 1281, dtype: int64

# %% [markdown]
# #### ¿Cuál es el gasto medio por país?

# %%
# your answer here
avg_country = orders.groupby('Country')['amount_spent'].agg('mean')
avg_country
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# ...

# %% [markdown]
# #### ¿Cuál es el artículo más caro?

# %%
# your answer here
sku_max = orders.loc[orders['UnitPrice'].idxmax(), 'StockCode']
sku_max
# Out:
# 'POST'

# %% [markdown]
# #### ¿Cuál fue la cantidad media gastada al año?

# %%
# your answer here
qty_mean_year = orders.loc[orders['StockCode'] == 'POST', 'Quantity'].mean()
qty_mean_year
# Out:
# np.float64(2.8389444949954505)
